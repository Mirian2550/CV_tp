# %%
# !pip install torch torchvision torchaudio
# !pip install requests pydantic opencv-python gdown
# !pip install git+https://github.com/facebookresearch/detectron2.git
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.19.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (2.9.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic) (4.12.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-bujjdd4l
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-bujjdd4l
#   Resolved https://github.com/facebookresearch/detectron2.git to commit ebe8b45437f86395352ab13402ba45b75b4d1ddb
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (10.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.8)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.4.0)
# Requirement already satisfied: yacs>=0.1.8 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.66.5)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.17.0)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (1.3.2)
# Requirement already satisfied: black in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (24.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (24.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.26.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1->detectron2==0.6) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath<0.1.10,>=0.1.7->detectron2==0.6) (2.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.3.6)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.12.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import subprocess
import torch
import json
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2.data.datasets import register_coco_instances
from detectron2 import model_zoo

# %%
class FruitDetector:
    """
    A class used to download, filter, and train a fruit detection model using Detectron2.

    Attributes:
    -----------
    train_dataset_path : str
        The path to the training dataset directory.
    test_dataset_path : str
        The path to the testing dataset directory.
    output_dir : str
        The directory where the model and results will be saved.
    num_classes : int
        Number of target classes for detection.
    base_lr : float
        The base learning rate for the model.
    max_iter : int
        Maximum number of iterations for training.
    batch_size : int
        The batch size used for training.
    num_workers : int
        Number of worker threads used for loading data.
    device : str
        Device used for training and inference (CPU/GPU).
    classes_to_keep : list
        List of classes to keep from the dataset.
    """

    def __init__(self, train_dataset_path, test_dataset_path,
                 output_dir="frutas_deteccion_objetos", num_classes=4, base_lr=0.0025,
                 max_iter=2500, batch_size=2, num_workers=2, device=None):
        """
        Initializes the FruitDetector class with dataset paths, training parameters, and filtering setup.

        Parameters:
        -----------
        train_dataset_path : str
            The path to the training dataset directory.
        test_dataset_path : str
            The path to the testing dataset directory.
        output_dir : str
            The directory where the model and results will be saved.
        num_classes : int
            Number of target classes for detection.
        base_lr : float
            The base learning rate for the model.
        max_iter : int
            Maximum number of iterations for training.
        batch_size : int
            The batch size used for training.
        num_workers : int
            Number of worker threads used for loading data.
        device : str
            Device used for training and inference (CPU/GPU). If None, automatically detects GPU or CPU.
        """
        self.train_dataset_path = train_dataset_path
        self.test_dataset_path = test_dataset_path
        self.num_classes = num_classes
        self.output_dir = output_dir
        self.base_lr = base_lr
        self.max_iter = max_iter
        self.batch_size = batch_size
        self.num_workers = num_workers

        # Detect device if not manually specified
        if device:
            self.device = device
        else:
            self.device = "cuda" if torch.cuda.is_available() else "cpu"

        print(f"Using device: {self.device}")

        self.classes_to_keep = ['apple', 'banana', 'orange', 'pear']

        self._download_dataset()
        self._filter_dataset()
        self._register_datasets()
        self.cfg = self._setup_cfg()

    def _download_dataset(self):
        """
        Downloads the dataset from Roboflow if it's not available locally.
        """
        if not os.path.exists(self.train_dataset_path) or not os.path.exists(self.test_dataset_path):
            print("Descargando el dataset desde Roboflow...")
            subprocess.run(
                'curl -L "https://universe.roboflow.com/ds/GcqspXimqf?key=CjGlzoKQxq" > roboflow.zip',
                shell=True)
            subprocess.run("unzip roboflow.zip", shell=True)
            os.remove("roboflow.zip")
            print("Dataset descargado, extraído y el archivo .zip eliminado.")
        else:
            print("El dataset ya está disponible.")

    def _filter_dataset(self):
        """
        Filters the dataset annotations and removes any images that do not contain the relevant classes.
        """
        def filter_annotations(json_path, dataset_path):
            with open(json_path, 'r') as f:
                data = json.load(f)

            filtered_images = []
            filtered_annotations = []
            class_ids_to_keep = [
                data['categories'].index(c) for c in data['categories'] if c['name'] in self.classes_to_keep
            ]

            for annotation in data['annotations']:
                if annotation['category_id'] in class_ids_to_keep:
                    filtered_annotations.append(annotation)

            for image in data['images']:
                image_annotations = [a for a in filtered_annotations if a['image_id'] == image['id']]
                if image_annotations:
                    filtered_images.append(image)
                else:
                    image_path = os.path.join(dataset_path, image['file_name'])
                    if os.path.exists(image_path):
                        os.remove(image_path)

            data['images'] = filtered_images
            data['annotations'] = filtered_annotations
            data['categories'] = [c for c in data['categories'] if c['name'] in self.classes_to_keep]

            with open(json_path, 'w') as f:
                json.dump(data, f)

        filter_annotations(f"{self.train_dataset_path}/_annotations.coco.json", self.train_dataset_path)
        filter_annotations(f"{self.test_dataset_path}/_annotations.coco.json", self.test_dataset_path)

    def _register_datasets(self):
        """
        Registers the filtered datasets for training and testing in the Detectron2 framework.
        """
        register_coco_instances("fruit_dataset_train", {},
                                f"{self.train_dataset_path}/_annotations.coco.json", self.train_dataset_path)
        register_coco_instances("fruit_dataset_test", {},
                                f"{self.test_dataset_path}/_annotations.coco.json", self.test_dataset_path)

    def _setup_cfg(self):
        """
        Sets up the configuration for the Detectron2 model and training parameters.
        """
        cfg = get_cfg()
        cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
        cfg.DATASETS.TRAIN = ("fruit_dataset_train",)
        cfg.DATASETS.TEST = ("fruit_dataset_test",)
        cfg.DATALOADER.NUM_WORKERS = self.num_workers
        cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml")
        cfg.SOLVER.IMS_PER_BATCH = self.batch_size
        cfg.SOLVER.BASE_LR = self.base_lr
        cfg.SOLVER.MAX_ITER = self.max_iter
        cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128
        cfg.MODEL.ROI_HEADS.NUM_CLASSES = self.num_classes
        cfg.OUTPUT_DIR = self.output_dir
        cfg.MODEL.DEVICE = self.device
        os.makedirs(self.output_dir, exist_ok=True)
        return cfg

    def train(self, resume=False):
        """
        Starts the training process for the model.

        Parameters:
        -----------
        resume : bool
            Whether to resume training from the last checkpoint.
        """
        trainer = DefaultTrainer(self.cfg)
        trainer.resume_or_load(resume=resume)
        trainer.train()

# %% [markdown]
# Entrenar Modelo ajuste fino

# %%
train_dataset_path = "train"
test_dataset_path = "test"

fruit_detector = FruitDetector(train_dataset_path, test_dataset_path)
fruit_detector.train(resume=False)
# Out:
# Using device: cuda
# Descargando el dataset desde Roboflow...
# Dataset descargado, extraído y el archivo .zip eliminado.
# [10/03 16:08:12 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=5, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=16, bias=True)
#     )
#   )
# )
# WARNING [10/03 16:08:12 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [10/03 16:08:12 d2.data.datasets.coco]: Loaded 2475 images in COCO format from train/_annotations.coco.json
# [10/03 16:08:12 d2.data.build]: Removed 0 images with no usable annotations. 2475 images left.
# [10/03 16:08:12 d2.data.build]: Distribution of instances among all 4 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   apple    | 1734         |   banana   | 3417         |   orange   | 1020         |
# |    pear    | 813          |            |              |            |              |
# |   total    | 6984         |            |              |            |              |
# [10/03 16:08:12 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [10/03 16:08:12 d2.data.build]: Using training sampler TrainingSampler
# [10/03 16:08:12 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/03 16:08:12 d2.data.common]: Serializing 2475 elements to byte tensors and concatenating them all ...
# [10/03 16:08:12 d2.data.common]: Serialized dataset takes 0.77 MiB
# [10/03 16:08:12 d2.data.build]: Making batched data loader with batch_size=2
# WARNING [10/03 16:08:12 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [10/03 16:08:12 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl ...
# model_final_280758.pkl: 167MB [00:00, 200MB/s]
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (5, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (5,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (16, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (16,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# [10/03 16:08:13 d2.engine.train_loop]: Starting training from iteration 0
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [10/03 16:08:25 d2.utils.events]:  eta: 0:13:14  iter: 19  total_loss: 2.32  loss_cls: 1.444  loss_box_reg: 0.9197  loss_rpn_cls: 0.004708  loss_rpn_loc: 0.005475    time: 0.3215  last_time: 0.3289  data_time: 0.0205  last_data_time: 0.0049   lr: 4.9952e-05  max_mem: 1736M
# [10/03 16:08:35 d2.utils.events]:  eta: 0:13:08  iter: 39  total_loss: 1.825  loss_cls: 0.8976  loss_box_reg: 0.9224  loss_rpn_cls: 0.003367  loss_rpn_loc: 0.007422    time: 0.3206  last_time: 0.3202  data_time: 0.0147  last_data_time: 0.0056   lr: 9.9902e-05  max_mem: 1737M
# [10/03 16:08:40 d2.utils.events]:  eta: 0:12:38  iter: 59  total_loss: 1.552  loss_cls: 0.608  loss_box_reg: 0.9164  loss_rpn_cls: 0.008533  loss_rpn_loc: 0.007636    time: 0.3098  last_time: 0.2604  data_time: 0.0103  last_data_time: 0.0130   lr: 0.00014985  max_mem: 1737M
# [10/03 16:08:46 d2.utils.events]:  eta: 0:11:57  iter: 79  total_loss: 1.32  loss_cls: 0.4489  loss_box_reg: 0.8661  loss_rpn_cls: 0.004691  loss_rpn_loc: 0.005581    time: 0.3029  last_time: 0.3006  data_time: 0.0118  last_data_time: 0.0110   lr: 0.0001998  max_mem: 1737M
# [10/03 16:08:52 d2.utils.events]:  eta: 0:11:47  iter: 99  total_loss: 1.104  loss_cls: 0.33  loss_box_reg: 0.7631  loss_rpn_cls: 0.00146  loss_rpn_loc: 0.006347    time: 0.3018  last_time: 0.3250  data_time: 0.0109  last_data_time: 0.0062   lr: 0.00024975  max_mem: 1737M
# [10/03 16:08:58 d2.utils.events]:  eta: 0:11:35  iter: 119  total_loss: 0.9552  loss_cls: 0.2733  loss_box_reg: 0.661  loss_rpn_cls: 0.00408  loss_rpn_loc: 0.008018    time: 0.2982  last_time: 0.2915  data_time: 0.0088  last_data_time: 0.0056   lr: 0.0002997  max_mem: 1737M
# [10/03 16:09:04 d2.utils.events]:  eta: 0:11:30  iter: 139  total_loss: 0.8306  loss_cls: 0.2264  loss_box_reg: 0.5724  loss_rpn_cls: 0.0009049  loss_rpn_loc: 0.009245    time: 0.2991  last_time: 0.2493  data_time: 0.0166  last_data_time: 0.0053   lr: 0.00034965  max_mem: 1737M
# [10/03 16:09:10 d2.utils.events]:  eta: 0:11:24  iter: 159  total_loss: 0.6644  loss_cls: 0.1881  loss_box_reg: 0.4616  loss_rpn_cls: 0.0002799  loss_rpn_loc: 0.008171    time: 0.2981  last_time: 0.2963  data_time: 0.0086  last_data_time: 0.0054   lr: 0.0003996  max_mem: 1737M
# [10/03 16:09:16 d2.utils.events]:  eta: 0:11:24  iter: 179  total_loss: 0.5258  loss_cls: 0.1558  loss_box_reg: 0.3516  loss_rpn_cls: 0.0008898  loss_rpn_loc: 0.008848    time: 0.2980  last_time: 0.3031  data_time: 0.0092  last_data_time: 0.0118   lr: 0.00044955  max_mem: 1737M
# [10/03 16:09:21 d2.utils.events]:  eta: 0:11:16  iter: 199  total_loss: 0.449  loss_cls: 0.1442  loss_box_reg: 0.285  loss_rpn_cls: 7.517e-05  loss_rpn_loc: 0.006508    time: 0.2973  last_time: 0.2509  data_time: 0.0098  last_data_time: 0.0063   lr: 0.0004995  max_mem: 1737M
# [10/03 16:09:27 d2.utils.events]:  eta: 0:11:11  iter: 219  total_loss: 0.4301  loss_cls: 0.1241  loss_box_reg: 0.295  loss_rpn_cls: 0.0002477  loss_rpn_loc: 0.007093    time: 0.2969  last_time: 0.2951  data_time: 0.0079  last_data_time: 0.0050   lr: 0.00054945  max_mem: 1737M
# [10/03 16:09:34 d2.utils.events]:  eta: 0:11:09  iter: 239  total_loss: 0.4314  loss_cls: 0.1188  loss_box_reg: 0.2946  loss_rpn_cls: 0.0002097  loss_rpn_loc: 0.00697    time: 0.2987  last_time: 0.3014  data_time: 0.0134  last_data_time: 0.0054   lr: 0.0005994  max_mem: 1737M
# [10/03 16:09:40 d2.utils.events]:  eta: 0:11:04  iter: 259  total_loss: 0.4108  loss_cls: 0.1287  loss_box_reg: 0.2717  loss_rpn_cls: 4.266e-05  loss_rpn_loc: 0.005817    time: 0.2995  last_time: 0.3015  data_time: 0.0103  last_data_time: 0.0060   lr: 0.00064935  max_mem: 1737M
# [10/03 16:09:46 d2.utils.events]:  eta: 0:11:01  iter: 279  total_loss: 0.4301  loss_cls: 0.1104  loss_box_reg: 0.3132  loss_rpn_cls: 0.0001987  loss_rpn_loc: 0.006702    time: 0.3008  last_time: 0.2943  data_time: 0.0111  last_data_time: 0.0206   lr: 0.0006993  max_mem: 1737M
# [10/03 16:09:52 d2.utils.events]:  eta: 0:10:57  iter: 299  total_loss: 0.4161  loss_cls: 0.1073  loss_box_reg: 0.3038  loss_rpn_cls: 8.399e-05  loss_rpn_loc: 0.005732    time: 0.3008  last_time: 0.3071  data_time: 0.0095  last_data_time: 0.0055   lr: 0.00074925  max_mem: 1737M
# [10/03 16:09:59 d2.utils.events]:  eta: 0:10:53  iter: 319  total_loss: 0.3633  loss_cls: 0.09555  loss_box_reg: 0.2559  loss_rpn_cls: 9.333e-05  loss_rpn_loc: 0.006852    time: 0.3017  last_time: 0.3015  data_time: 0.0097  last_data_time: 0.0193   lr: 0.0007992  max_mem: 1737M
# [10/03 16:10:04 d2.utils.events]:  eta: 0:10:47  iter: 339  total_loss: 0.3746  loss_cls: 0.0852  loss_box_reg: 0.2739  loss_rpn_cls: 0.000168  loss_rpn_loc: 0.006422    time: 0.3014  last_time: 0.2859  data_time: 0.0123  last_data_time: 0.0055   lr: 0.00084915  max_mem: 1737M
# [10/03 16:10:10 d2.utils.events]:  eta: 0:10:41  iter: 359  total_loss: 0.3108  loss_cls: 0.08427  loss_box_reg: 0.226  loss_rpn_cls: 0.0002241  loss_rpn_loc: 0.00559    time: 0.3007  last_time: 0.3054  data_time: 0.0083  last_data_time: 0.0114   lr: 0.0008991  max_mem: 1737M
# [10/03 16:10:17 d2.utils.events]:  eta: 0:10:37  iter: 379  total_loss: 0.36  loss_cls: 0.1009  loss_box_reg: 0.2411  loss_rpn_cls: 0.000239  loss_rpn_loc: 0.006292    time: 0.3018  last_time: 0.2961  data_time: 0.0122  last_data_time: 0.0117   lr: 0.00094905  max_mem: 1737M
# [10/03 16:10:23 d2.utils.events]:  eta: 0:10:31  iter: 399  total_loss: 0.3602  loss_cls: 0.08941  loss_box_reg: 0.2743  loss_rpn_cls: 0.0002373  loss_rpn_loc: 0.005832    time: 0.3014  last_time: 0.3089  data_time: 0.0101  last_data_time: 0.0113   lr: 0.000999  max_mem: 1737M
# [10/03 16:10:29 d2.utils.events]:  eta: 0:10:26  iter: 419  total_loss: 0.3389  loss_cls: 0.07272  loss_box_reg: 0.2575  loss_rpn_cls: 0.0001335  loss_rpn_loc: 0.004905    time: 0.3016  last_time: 0.3192  data_time: 0.0114  last_data_time: 0.0219   lr: 0.001049  max_mem: 1737M
# [10/03 16:10:35 d2.utils.events]:  eta: 0:10:20  iter: 439  total_loss: 0.3717  loss_cls: 0.07806  loss_box_reg: 0.2633  loss_rpn_cls: 0.0002508  loss_rpn_loc: 0.00624    time: 0.3016  last_time: 0.3073  data_time: 0.0104  last_data_time: 0.0059   lr: 0.0010989  max_mem: 1737M
# [10/03 16:10:41 d2.utils.events]:  eta: 0:10:15  iter: 459  total_loss: 0.3559  loss_cls: 0.07838  loss_box_reg: 0.2676  loss_rpn_cls: 0.0002246  loss_rpn_loc: 0.005232    time: 0.3018  last_time: 0.2843  data_time: 0.0102  last_data_time: 0.0328   lr: 0.0011489  max_mem: 1737M
# [10/03 16:10:47 d2.utils.events]:  eta: 0:10:09  iter: 479  total_loss: 0.3182  loss_cls: 0.06953  loss_box_reg: 0.2387  loss_rpn_cls: 0.0002398  loss_rpn_loc: 0.005922    time: 0.3018  last_time: 0.3425  data_time: 0.0154  last_data_time: 0.0159   lr: 0.0011988  max_mem: 1737M
# [10/03 16:10:53 d2.utils.events]:  eta: 0:10:02  iter: 499  total_loss: 0.34  loss_cls: 0.0747  loss_box_reg: 0.2528  loss_rpn_cls: 0.00043  loss_rpn_loc: 0.006232    time: 0.3017  last_time: 0.2901  data_time: 0.0105  last_data_time: 0.0050   lr: 0.0012488  max_mem: 1737M
# [10/03 16:10:59 d2.utils.events]:  eta: 0:09:58  iter: 519  total_loss: 0.3457  loss_cls: 0.1077  loss_box_reg: 0.2241  loss_rpn_cls: 0.0007974  loss_rpn_loc: 0.005925    time: 0.3026  last_time: 0.2907  data_time: 0.0176  last_data_time: 0.0052   lr: 0.0012987  max_mem: 1737M
# [10/03 16:11:05 d2.utils.events]:  eta: 0:09:52  iter: 539  total_loss: 0.3254  loss_cls: 0.08849  loss_box_reg: 0.2224  loss_rpn_cls: 0.0002857  loss_rpn_loc: 0.005065    time: 0.3025  last_time: 0.3368  data_time: 0.0070  last_data_time: 0.0053   lr: 0.0013487  max_mem: 1737M
# [10/03 16:11:12 d2.utils.events]:  eta: 0:09:47  iter: 559  total_loss: 0.3306  loss_cls: 0.08937  loss_box_reg: 0.2298  loss_rpn_cls: 0.0001294  loss_rpn_loc: 0.006709    time: 0.3027  last_time: 0.3413  data_time: 0.0096  last_data_time: 0.0051   lr: 0.0013986  max_mem: 1737M
# [10/03 16:11:18 d2.utils.events]:  eta: 0:09:41  iter: 579  total_loss: 0.2968  loss_cls: 0.06811  loss_box_reg: 0.2246  loss_rpn_cls: 0.0003209  loss_rpn_loc: 0.005555    time: 0.3027  last_time: 0.2756  data_time: 0.0123  last_data_time: 0.0053   lr: 0.0014486  max_mem: 1737M
# [10/03 16:11:24 d2.utils.events]:  eta: 0:09:35  iter: 599  total_loss: 0.2885  loss_cls: 0.06154  loss_box_reg: 0.2267  loss_rpn_cls: 0.0001829  loss_rpn_loc: 0.005809    time: 0.3026  last_time: 0.2959  data_time: 0.0092  last_data_time: 0.0116   lr: 0.0014985  max_mem: 1737M
# [10/03 16:11:30 d2.utils.events]:  eta: 0:09:30  iter: 619  total_loss: 0.3159  loss_cls: 0.07556  loss_box_reg: 0.2368  loss_rpn_cls: 9.612e-05  loss_rpn_loc: 0.006651    time: 0.3032  last_time: 0.3381  data_time: 0.0152  last_data_time: 0.0056   lr: 0.0015485  max_mem: 1737M
# [10/03 16:11:36 d2.utils.events]:  eta: 0:09:23  iter: 639  total_loss: 0.3253  loss_cls: 0.06379  loss_box_reg: 0.2504  loss_rpn_cls: 0.0002225  loss_rpn_loc: 0.005705    time: 0.3029  last_time: 0.3078  data_time: 0.0082  last_data_time: 0.0053   lr: 0.0015984  max_mem: 1737M
# [10/03 16:11:43 d2.utils.events]:  eta: 0:09:18  iter: 659  total_loss: 0.2947  loss_cls: 0.05432  loss_box_reg: 0.2197  loss_rpn_cls: 0.0003263  loss_rpn_loc: 0.006111    time: 0.3037  last_time: 0.2920  data_time: 0.0132  last_data_time: 0.0243   lr: 0.0016484  max_mem: 1737M
# [10/03 16:11:49 d2.utils.events]:  eta: 0:09:12  iter: 679  total_loss: 0.304  loss_cls: 0.07666  loss_box_reg: 0.2262  loss_rpn_cls: 0.0002396  loss_rpn_loc: 0.005223    time: 0.3036  last_time: 0.2918  data_time: 0.0090  last_data_time: 0.0056   lr: 0.0016983  max_mem: 1737M
# [10/03 16:11:55 d2.utils.events]:  eta: 0:09:06  iter: 699  total_loss: 0.2813  loss_cls: 0.05542  loss_box_reg: 0.2224  loss_rpn_cls: 9.203e-05  loss_rpn_loc: 0.005298    time: 0.3039  last_time: 0.3622  data_time: 0.0115  last_data_time: 0.0182   lr: 0.0017483  max_mem: 1737M
# [10/03 16:12:01 d2.utils.events]:  eta: 0:09:00  iter: 719  total_loss: 0.3067  loss_cls: 0.05592  loss_box_reg: 0.2243  loss_rpn_cls: 0.0001328  loss_rpn_loc: 0.005351    time: 0.3043  last_time: 0.2657  data_time: 0.0091  last_data_time: 0.0054   lr: 0.0017982  max_mem: 1737M
# [10/03 16:12:08 d2.utils.events]:  eta: 0:08:55  iter: 739  total_loss: 0.3218  loss_cls: 0.08495  loss_box_reg: 0.2321  loss_rpn_cls: 0.0002117  loss_rpn_loc: 0.007647    time: 0.3045  last_time: 0.3508  data_time: 0.0065  last_data_time: 0.0052   lr: 0.0018482  max_mem: 1737M
# [10/03 16:12:14 d2.utils.events]:  eta: 0:08:49  iter: 759  total_loss: 0.2752  loss_cls: 0.06347  loss_box_reg: 0.2079  loss_rpn_cls: 0.0002311  loss_rpn_loc: 0.005179    time: 0.3049  last_time: 0.3139  data_time: 0.0143  last_data_time: 0.0111   lr: 0.0018981  max_mem: 1737M
# [10/03 16:12:20 d2.utils.events]:  eta: 0:08:43  iter: 779  total_loss: 0.2836  loss_cls: 0.06626  loss_box_reg: 0.2094  loss_rpn_cls: 0.0001458  loss_rpn_loc: 0.00476    time: 0.3048  last_time: 0.2955  data_time: 0.0094  last_data_time: 0.0055   lr: 0.0019481  max_mem: 1737M
# [10/03 16:12:27 d2.utils.events]:  eta: 0:08:37  iter: 799  total_loss: 0.3091  loss_cls: 0.07443  loss_box_reg: 0.2175  loss_rpn_cls: 0.0002405  loss_rpn_loc: 0.005882    time: 0.3053  last_time: 0.3410  data_time: 0.0169  last_data_time: 0.0272   lr: 0.001998  max_mem: 1737M
# [10/03 16:12:33 d2.utils.events]:  eta: 0:08:31  iter: 819  total_loss: 0.2858  loss_cls: 0.07489  loss_box_reg: 0.2014  loss_rpn_cls: 0.0002783  loss_rpn_loc: 0.004878    time: 0.3053  last_time: 0.2944  data_time: 0.0099  last_data_time: 0.0060   lr: 0.002048  max_mem: 1737M
# [10/03 16:12:39 d2.utils.events]:  eta: 0:08:26  iter: 839  total_loss: 0.3329  loss_cls: 0.08225  loss_box_reg: 0.222  loss_rpn_cls: 0.0004505  loss_rpn_loc: 0.006377    time: 0.3054  last_time: 0.3229  data_time: 0.0095  last_data_time: 0.0164   lr: 0.0020979  max_mem: 1737M
# [10/03 16:12:45 d2.utils.events]:  eta: 0:08:20  iter: 859  total_loss: 0.3262  loss_cls: 0.07602  loss_box_reg: 0.2496  loss_rpn_cls: 0.0005697  loss_rpn_loc: 0.006584    time: 0.3057  last_time: 0.3138  data_time: 0.0165  last_data_time: 0.0167   lr: 0.0021479  max_mem: 1737M
# [10/03 16:12:52 d2.utils.events]:  eta: 0:08:14  iter: 879  total_loss: 0.2847  loss_cls: 0.04903  loss_box_reg: 0.2302  loss_rpn_cls: 0.0004354  loss_rpn_loc: 0.005368    time: 0.3061  last_time: 0.3322  data_time: 0.0095  last_data_time: 0.0054   lr: 0.0021978  max_mem: 1737M
# [10/03 16:12:58 d2.utils.events]:  eta: 0:08:09  iter: 899  total_loss: 0.3266  loss_cls: 0.07299  loss_box_reg: 0.2456  loss_rpn_cls: 0.0002191  loss_rpn_loc: 0.005601    time: 0.3066  last_time: 0.3112  data_time: 0.0146  last_data_time: 0.0056   lr: 0.0022478  max_mem: 1737M
# [10/03 16:13:04 d2.utils.events]:  eta: 0:08:03  iter: 919  total_loss: 0.3133  loss_cls: 0.08888  loss_box_reg: 0.226  loss_rpn_cls: 0.0003926  loss_rpn_loc: 0.006051    time: 0.3065  last_time: 0.3194  data_time: 0.0083  last_data_time: 0.0055   lr: 0.0022977  max_mem: 1737M
# [10/03 16:13:11 d2.utils.events]:  eta: 0:07:58  iter: 939  total_loss: 0.293  loss_cls: 0.07319  loss_box_reg: 0.2173  loss_rpn_cls: 0.0003904  loss_rpn_loc: 0.005719    time: 0.3068  last_time: 0.3083  data_time: 0.0173  last_data_time: 0.0065   lr: 0.0023477  max_mem: 1737M
# [10/03 16:13:17 d2.utils.events]:  eta: 0:07:52  iter: 959  total_loss: 0.2956  loss_cls: 0.07942  loss_box_reg: 0.1975  loss_rpn_cls: 0.0004173  loss_rpn_loc: 0.006878    time: 0.3067  last_time: 0.3424  data_time: 0.0080  last_data_time: 0.0056   lr: 0.0023976  max_mem: 1737M
# [10/03 16:13:23 d2.utils.events]:  eta: 0:07:45  iter: 979  total_loss: 0.3667  loss_cls: 0.09275  loss_box_reg: 0.2314  loss_rpn_cls: 0.0008587  loss_rpn_loc: 0.006148    time: 0.3065  last_time: 0.2670  data_time: 0.0085  last_data_time: 0.0053   lr: 0.0024476  max_mem: 1738M
# [10/03 16:13:29 d2.utils.events]:  eta: 0:07:39  iter: 999  total_loss: 0.3599  loss_cls: 0.09397  loss_box_reg: 0.2419  loss_rpn_cls: 0.0005429  loss_rpn_loc: 0.006518    time: 0.3069  last_time: 0.3148  data_time: 0.0117  last_data_time: 0.0134   lr: 0.0024975  max_mem: 1738M
# [10/03 16:13:35 d2.utils.events]:  eta: 0:07:33  iter: 1019  total_loss: 0.314  loss_cls: 0.07704  loss_box_reg: 0.2255  loss_rpn_cls: 0.0006417  loss_rpn_loc: 0.004871    time: 0.3067  last_time: 0.3442  data_time: 0.0075  last_data_time: 0.0047   lr: 0.0025  max_mem: 1738M
# [10/03 16:13:41 d2.utils.events]:  eta: 0:07:26  iter: 1039  total_loss: 0.3335  loss_cls: 0.06489  loss_box_reg: 0.2643  loss_rpn_cls: 0.0005574  loss_rpn_loc: 0.006943    time: 0.3066  last_time: 0.2350  data_time: 0.0102  last_data_time: 0.0054   lr: 0.0025  max_mem: 1738M
# [10/03 16:13:47 d2.utils.events]:  eta: 0:07:21  iter: 1059  total_loss: 0.3198  loss_cls: 0.05959  loss_box_reg: 0.218  loss_rpn_cls: 0.0003772  loss_rpn_loc: 0.005017    time: 0.3066  last_time: 0.3522  data_time: 0.0077  last_data_time: 0.0162   lr: 0.0025  max_mem: 1738M
# [10/03 16:13:54 d2.utils.events]:  eta: 0:07:16  iter: 1079  total_loss: 0.3027  loss_cls: 0.07276  loss_box_reg: 0.2292  loss_rpn_cls: 0.0004875  loss_rpn_loc: 0.006144    time: 0.3069  last_time: 0.3699  data_time: 0.0165  last_data_time: 0.0233   lr: 0.0025  max_mem: 1738M
# [10/03 16:14:00 d2.utils.events]:  eta: 0:07:10  iter: 1099  total_loss: 0.2956  loss_cls: 0.0771  loss_box_reg: 0.2131  loss_rpn_cls: 0.0006035  loss_rpn_loc: 0.005387    time: 0.3071  last_time: 0.3056  data_time: 0.0113  last_data_time: 0.0159   lr: 0.0025  max_mem: 1738M
# [10/03 16:14:07 d2.utils.events]:  eta: 0:07:05  iter: 1119  total_loss: 0.3046  loss_cls: 0.06771  loss_box_reg: 0.2102  loss_rpn_cls: 0.0003394  loss_rpn_loc: 0.00604    time: 0.3073  last_time: 0.3103  data_time: 0.0131  last_data_time: 0.0190   lr: 0.0025  max_mem: 1738M
# [10/03 16:14:13 d2.utils.events]:  eta: 0:06:59  iter: 1139  total_loss: 0.3287  loss_cls: 0.07918  loss_box_reg: 0.2379  loss_rpn_cls: 0.0003397  loss_rpn_loc: 0.006643    time: 0.3075  last_time: 0.2752  data_time: 0.0098  last_data_time: 0.0055   lr: 0.0025  max_mem: 1738M
# [10/03 16:14:19 d2.utils.events]:  eta: 0:06:54  iter: 1159  total_loss: 0.279  loss_cls: 0.0673  loss_box_reg: 0.2  loss_rpn_cls: 0.0004093  loss_rpn_loc: 0.005773    time: 0.3077  last_time: 0.3443  data_time: 0.0091  last_data_time: 0.0051   lr: 0.0025  max_mem: 1738M
# [10/03 16:14:26 d2.utils.events]:  eta: 0:06:49  iter: 1179  total_loss: 0.2753  loss_cls: 0.05757  loss_box_reg: 0.2126  loss_rpn_cls: 0.0005399  loss_rpn_loc: 0.005284    time: 0.3079  last_time: 0.3221  data_time: 0.0152  last_data_time: 0.0054   lr: 0.0025  max_mem: 1738M
# [10/03 16:14:32 d2.utils.events]:  eta: 0:06:43  iter: 1199  total_loss: 0.2672  loss_cls: 0.05353  loss_box_reg: 0.2008  loss_rpn_cls: 0.0002898  loss_rpn_loc: 0.004845    time: 0.3079  last_time: 0.3011  data_time: 0.0079  last_data_time: 0.0130   lr: 0.0025  max_mem: 1738M
# [10/03 16:14:38 d2.utils.events]:  eta: 0:06:38  iter: 1219  total_loss: 0.328  loss_cls: 0.06861  loss_box_reg: 0.2432  loss_rpn_cls: 0.0006121  loss_rpn_loc: 0.005861    time: 0.3081  last_time: 0.3269  data_time: 0.0139  last_data_time: 0.0282   lr: 0.0025  max_mem: 1738M
# [10/03 16:14:45 d2.utils.events]:  eta: 0:06:32  iter: 1239  total_loss: 0.2812  loss_cls: 0.06432  loss_box_reg: 0.2124  loss_rpn_cls: 0.000458  loss_rpn_loc: 0.004938    time: 0.3081  last_time: 0.2948  data_time: 0.0079  last_data_time: 0.0058   lr: 0.0025  max_mem: 1738M
# [10/03 16:14:51 d2.utils.events]:  eta: 0:06:25  iter: 1259  total_loss: 0.3047  loss_cls: 0.0773  loss_box_reg: 0.2113  loss_rpn_cls: 0.0003955  loss_rpn_loc: 0.005981    time: 0.3080  last_time: 0.3641  data_time: 0.0085  last_data_time: 0.0211   lr: 0.0025  max_mem: 1738M
# [10/03 16:14:57 d2.utils.events]:  eta: 0:06:19  iter: 1279  total_loss: 0.2862  loss_cls: 0.06798  loss_box_reg: 0.2143  loss_rpn_cls: 0.0006495  loss_rpn_loc: 0.005133    time: 0.3084  last_time: 0.3496  data_time: 0.0125  last_data_time: 0.0167   lr: 0.0025  max_mem: 1738M
# [10/03 16:15:03 d2.utils.events]:  eta: 0:06:13  iter: 1299  total_loss: 0.2832  loss_cls: 0.06971  loss_box_reg: 0.2109  loss_rpn_cls: 0.0004952  loss_rpn_loc: 0.006106    time: 0.3084  last_time: 0.2886  data_time: 0.0082  last_data_time: 0.0059   lr: 0.0025  max_mem: 1738M
# [10/03 16:15:10 d2.utils.events]:  eta: 0:06:07  iter: 1319  total_loss: 0.2825  loss_cls: 0.05767  loss_box_reg: 0.2111  loss_rpn_cls: 0.000452  loss_rpn_loc: 0.00444    time: 0.3085  last_time: 0.3483  data_time: 0.0180  last_data_time: 0.0133   lr: 0.0025  max_mem: 1738M
# [10/03 16:15:16 d2.utils.events]:  eta: 0:06:01  iter: 1339  total_loss: 0.2832  loss_cls: 0.06044  loss_box_reg: 0.1803  loss_rpn_cls: 0.0004751  loss_rpn_loc: 0.005799    time: 0.3086  last_time: 0.3568  data_time: 0.0073  last_data_time: 0.0121   lr: 0.0025  max_mem: 1738M
# [10/03 16:15:23 d2.utils.events]:  eta: 0:05:55  iter: 1359  total_loss: 0.296  loss_cls: 0.07227  loss_box_reg: 0.2318  loss_rpn_cls: 0.0004803  loss_rpn_loc: 0.005409    time: 0.3089  last_time: 0.3453  data_time: 0.0167  last_data_time: 0.0059   lr: 0.0025  max_mem: 1738M
# [10/03 16:15:29 d2.utils.events]:  eta: 0:05:48  iter: 1379  total_loss: 0.2882  loss_cls: 0.06518  loss_box_reg: 0.2039  loss_rpn_cls: 0.0003501  loss_rpn_loc: 0.006129    time: 0.3089  last_time: 0.2739  data_time: 0.0074  last_data_time: 0.0050   lr: 0.0025  max_mem: 1738M
# [10/03 16:15:35 d2.utils.events]:  eta: 0:05:43  iter: 1399  total_loss: 0.2885  loss_cls: 0.07584  loss_box_reg: 0.2132  loss_rpn_cls: 0.0007653  loss_rpn_loc: 0.004311    time: 0.3091  last_time: 0.3363  data_time: 0.0138  last_data_time: 0.0267   lr: 0.0025  max_mem: 1738M
# [10/03 16:15:42 d2.utils.events]:  eta: 0:05:36  iter: 1419  total_loss: 0.2916  loss_cls: 0.06926  loss_box_reg: 0.1959  loss_rpn_cls: 0.0004574  loss_rpn_loc: 0.005183    time: 0.3091  last_time: 0.3130  data_time: 0.0115  last_data_time: 0.0053   lr: 0.0025  max_mem: 1738M
# [10/03 16:15:48 d2.utils.events]:  eta: 0:05:30  iter: 1439  total_loss: 0.2806  loss_cls: 0.07606  loss_box_reg: 0.1946  loss_rpn_cls: 0.0004824  loss_rpn_loc: 0.004743    time: 0.3091  last_time: 0.3293  data_time: 0.0079  last_data_time: 0.0115   lr: 0.0025  max_mem: 1738M
# [10/03 16:15:54 d2.utils.events]:  eta: 0:05:25  iter: 1459  total_loss: 0.2895  loss_cls: 0.06468  loss_box_reg: 0.2075  loss_rpn_cls: 0.0004029  loss_rpn_loc: 0.006487    time: 0.3094  last_time: 0.3437  data_time: 0.0144  last_data_time: 0.0053   lr: 0.0025  max_mem: 1738M
# [10/03 16:16:01 d2.utils.events]:  eta: 0:05:19  iter: 1479  total_loss: 0.2518  loss_cls: 0.05947  loss_box_reg: 0.1862  loss_rpn_cls: 0.0004197  loss_rpn_loc: 0.004325    time: 0.3095  last_time: 0.3096  data_time: 0.0084  last_data_time: 0.0055   lr: 0.0025  max_mem: 1738M
# [10/03 16:16:07 d2.utils.events]:  eta: 0:05:13  iter: 1499  total_loss: 0.2783  loss_cls: 0.06663  loss_box_reg: 0.1956  loss_rpn_cls: 0.0002966  loss_rpn_loc: 0.005882    time: 0.3096  last_time: 0.3503  data_time: 0.0094  last_data_time: 0.0165   lr: 0.0025  max_mem: 1738M
# [10/03 16:16:13 d2.utils.events]:  eta: 0:05:06  iter: 1519  total_loss: 0.2806  loss_cls: 0.05943  loss_box_reg: 0.2092  loss_rpn_cls: 0.0004464  loss_rpn_loc: 0.005793    time: 0.3096  last_time: 0.3109  data_time: 0.0089  last_data_time: 0.0062   lr: 0.0025  max_mem: 1738M
# [10/03 16:16:20 d2.utils.events]:  eta: 0:05:00  iter: 1539  total_loss: 0.2752  loss_cls: 0.07198  loss_box_reg: 0.1901  loss_rpn_cls: 0.0007053  loss_rpn_loc: 0.005153    time: 0.3098  last_time: 0.3015  data_time: 0.0118  last_data_time: 0.0056   lr: 0.0025  max_mem: 1738M
# [10/03 16:16:26 d2.utils.events]:  eta: 0:04:54  iter: 1559  total_loss: 0.271  loss_cls: 0.06321  loss_box_reg: 0.2024  loss_rpn_cls: 0.0004741  loss_rpn_loc: 0.005007    time: 0.3097  last_time: 0.2724  data_time: 0.0074  last_data_time: 0.0054   lr: 0.0025  max_mem: 1738M
# [10/03 16:16:32 d2.utils.events]:  eta: 0:04:48  iter: 1579  total_loss: 0.2996  loss_cls: 0.05455  loss_box_reg: 0.2211  loss_rpn_cls: 0.0004664  loss_rpn_loc: 0.004159    time: 0.3097  last_time: 0.2858  data_time: 0.0111  last_data_time: 0.0137   lr: 0.0025  max_mem: 1738M
# [10/03 16:16:38 d2.utils.events]:  eta: 0:04:42  iter: 1599  total_loss: 0.2866  loss_cls: 0.06468  loss_box_reg: 0.2094  loss_rpn_cls: 0.0004981  loss_rpn_loc: 0.006571    time: 0.3098  last_time: 0.3512  data_time: 0.0125  last_data_time: 0.0055   lr: 0.0025  max_mem: 1738M
# [10/03 16:16:45 d2.utils.events]:  eta: 0:04:35  iter: 1619  total_loss: 0.2825  loss_cls: 0.05873  loss_box_reg: 0.2091  loss_rpn_cls: 0.0003588  loss_rpn_loc: 0.00551    time: 0.3099  last_time: 0.3428  data_time: 0.0073  last_data_time: 0.0056   lr: 0.0025  max_mem: 1738M
# [10/03 16:16:51 d2.utils.events]:  eta: 0:04:29  iter: 1639  total_loss: 0.2737  loss_cls: 0.05122  loss_box_reg: 0.1996  loss_rpn_cls: 0.0003849  loss_rpn_loc: 0.004789    time: 0.3100  last_time: 0.3490  data_time: 0.0148  last_data_time: 0.0051   lr: 0.0025  max_mem: 1738M
# [10/03 16:16:58 d2.utils.events]:  eta: 0:04:23  iter: 1659  total_loss: 0.2625  loss_cls: 0.05485  loss_box_reg: 0.1985  loss_rpn_cls: 0.0003287  loss_rpn_loc: 0.005164    time: 0.3101  last_time: 0.3429  data_time: 0.0067  last_data_time: 0.0051   lr: 0.0025  max_mem: 1738M
# [10/03 16:17:04 d2.utils.events]:  eta: 0:04:17  iter: 1679  total_loss: 0.2702  loss_cls: 0.05581  loss_box_reg: 0.195  loss_rpn_cls: 0.0002662  loss_rpn_loc: 0.005402    time: 0.3100  last_time: 0.2922  data_time: 0.0125  last_data_time: 0.0182   lr: 0.0025  max_mem: 1738M
# [10/03 16:17:10 d2.utils.events]:  eta: 0:04:10  iter: 1699  total_loss: 0.2873  loss_cls: 0.06628  loss_box_reg: 0.2063  loss_rpn_cls: 0.0005179  loss_rpn_loc: 0.006672    time: 0.3099  last_time: 0.2943  data_time: 0.0106  last_data_time: 0.0051   lr: 0.0025  max_mem: 1738M
# [10/03 16:17:16 d2.utils.events]:  eta: 0:04:04  iter: 1719  total_loss: 0.2607  loss_cls: 0.05431  loss_box_reg: 0.1921  loss_rpn_cls: 0.0003817  loss_rpn_loc: 0.00481    time: 0.3099  last_time: 0.2748  data_time: 0.0092  last_data_time: 0.0217   lr: 0.0025  max_mem: 1738M
# [10/03 16:17:22 d2.utils.events]:  eta: 0:03:58  iter: 1739  total_loss: 0.2529  loss_cls: 0.05921  loss_box_reg: 0.1761  loss_rpn_cls: 0.0004375  loss_rpn_loc: 0.005489    time: 0.3100  last_time: 0.3441  data_time: 0.0129  last_data_time: 0.0056   lr: 0.0025  max_mem: 1738M
# [10/03 16:17:29 d2.utils.events]:  eta: 0:03:51  iter: 1759  total_loss: 0.2643  loss_cls: 0.06184  loss_box_reg: 0.1834  loss_rpn_cls: 0.0004939  loss_rpn_loc: 0.005103    time: 0.3100  last_time: 0.3436  data_time: 0.0070  last_data_time: 0.0051   lr: 0.0025  max_mem: 1738M
# [10/03 16:17:35 d2.utils.events]:  eta: 0:03:45  iter: 1779  total_loss: 0.2828  loss_cls: 0.07145  loss_box_reg: 0.1901  loss_rpn_cls: 0.0004606  loss_rpn_loc: 0.005191    time: 0.3102  last_time: 0.3322  data_time: 0.0166  last_data_time: 0.0195   lr: 0.0025  max_mem: 1738M
# [10/03 16:17:41 d2.utils.events]:  eta: 0:03:39  iter: 1799  total_loss: 0.255  loss_cls: 0.05502  loss_box_reg: 0.1855  loss_rpn_cls: 0.0005003  loss_rpn_loc: 0.005725    time: 0.3101  last_time: 0.3544  data_time: 0.0094  last_data_time: 0.0205   lr: 0.0025  max_mem: 1738M
# [10/03 16:17:48 d2.utils.events]:  eta: 0:03:33  iter: 1819  total_loss: 0.2457  loss_cls: 0.05163  loss_box_reg: 0.1835  loss_rpn_cls: 0.0003807  loss_rpn_loc: 0.004181    time: 0.3103  last_time: 0.3318  data_time: 0.0103  last_data_time: 0.0168   lr: 0.0025  max_mem: 1738M
# [10/03 16:17:54 d2.utils.events]:  eta: 0:03:27  iter: 1839  total_loss: 0.2674  loss_cls: 0.06544  loss_box_reg: 0.1942  loss_rpn_cls: 0.0002656  loss_rpn_loc: 0.004522    time: 0.3104  last_time: 0.2657  data_time: 0.0123  last_data_time: 0.0116   lr: 0.0025  max_mem: 1738M
# [10/03 16:18:00 d2.utils.events]:  eta: 0:03:20  iter: 1859  total_loss: 0.2581  loss_cls: 0.04746  loss_box_reg: 0.2023  loss_rpn_cls: 0.0003097  loss_rpn_loc: 0.004282    time: 0.3104  last_time: 0.3242  data_time: 0.0078  last_data_time: 0.0158   lr: 0.0025  max_mem: 1738M
# [10/03 16:18:07 d2.utils.events]:  eta: 0:03:14  iter: 1879  total_loss: 0.2413  loss_cls: 0.05447  loss_box_reg: 0.1736  loss_rpn_cls: 0.0003914  loss_rpn_loc: 0.005176    time: 0.3105  last_time: 0.3103  data_time: 0.0159  last_data_time: 0.0054   lr: 0.0025  max_mem: 1738M
# [10/03 16:18:13 d2.utils.events]:  eta: 0:03:08  iter: 1899  total_loss: 0.2815  loss_cls: 0.05485  loss_box_reg: 0.2022  loss_rpn_cls: 0.0003658  loss_rpn_loc: 0.00451    time: 0.3105  last_time: 0.3458  data_time: 0.0063  last_data_time: 0.0072   lr: 0.0025  max_mem: 1738M
# [10/03 16:18:20 d2.utils.events]:  eta: 0:03:01  iter: 1919  total_loss: 0.2374  loss_cls: 0.06185  loss_box_reg: 0.172  loss_rpn_cls: 0.0003418  loss_rpn_loc: 0.004762    time: 0.3108  last_time: 0.2761  data_time: 0.0177  last_data_time: 0.0056   lr: 0.0025  max_mem: 1738M
# [10/03 16:18:26 d2.utils.events]:  eta: 0:02:55  iter: 1939  total_loss: 0.2679  loss_cls: 0.07017  loss_box_reg: 0.1748  loss_rpn_cls: 0.0002418  loss_rpn_loc: 0.003564    time: 0.3108  last_time: 0.2985  data_time: 0.0108  last_data_time: 0.0123   lr: 0.0025  max_mem: 1738M
# [10/03 16:18:32 d2.utils.events]:  eta: 0:02:49  iter: 1959  total_loss: 0.2639  loss_cls: 0.06898  loss_box_reg: 0.1933  loss_rpn_cls: 0.0003883  loss_rpn_loc: 0.004139    time: 0.3109  last_time: 0.3323  data_time: 0.0125  last_data_time: 0.0200   lr: 0.0025  max_mem: 1738M
# [10/03 16:18:39 d2.utils.events]:  eta: 0:02:43  iter: 1979  total_loss: 0.2858  loss_cls: 0.06866  loss_box_reg: 0.1946  loss_rpn_cls: 0.0003991  loss_rpn_loc: 0.005099    time: 0.3109  last_time: 0.3096  data_time: 0.0099  last_data_time: 0.0123   lr: 0.0025  max_mem: 1738M
# [10/03 16:18:45 d2.utils.events]:  eta: 0:02:37  iter: 1999  total_loss: 0.2206  loss_cls: 0.04761  loss_box_reg: 0.1639  loss_rpn_cls: 0.000239  loss_rpn_loc: 0.003416    time: 0.3110  last_time: 0.3215  data_time: 0.0096  last_data_time: 0.0063   lr: 0.0025  max_mem: 1738M
# [10/03 16:18:51 d2.utils.events]:  eta: 0:02:30  iter: 2019  total_loss: 0.2556  loss_cls: 0.05593  loss_box_reg: 0.2022  loss_rpn_cls: 0.0004818  loss_rpn_loc: 0.005038    time: 0.3108  last_time: 0.2299  data_time: 0.0154  last_data_time: 0.0053   lr: 0.0025  max_mem: 1738M
# [10/03 16:18:57 d2.utils.events]:  eta: 0:02:24  iter: 2039  total_loss: 0.2452  loss_cls: 0.05301  loss_box_reg: 0.1847  loss_rpn_cls: 0.0003087  loss_rpn_loc: 0.006053    time: 0.3107  last_time: 0.2723  data_time: 0.0073  last_data_time: 0.0064   lr: 0.0025  max_mem: 1738M
# [10/03 16:19:03 d2.utils.events]:  eta: 0:02:18  iter: 2059  total_loss: 0.2424  loss_cls: 0.0491  loss_box_reg: 0.1845  loss_rpn_cls: 0.0003667  loss_rpn_loc: 0.004253    time: 0.3108  last_time: 0.2809  data_time: 0.0165  last_data_time: 0.0124   lr: 0.0025  max_mem: 1738M
# [10/03 16:19:10 d2.utils.events]:  eta: 0:02:11  iter: 2079  total_loss: 0.2468  loss_cls: 0.05408  loss_box_reg: 0.1893  loss_rpn_cls: 0.0002782  loss_rpn_loc: 0.004882    time: 0.3109  last_time: 0.3480  data_time: 0.0094  last_data_time: 0.0122   lr: 0.0025  max_mem: 1738M
# [10/03 16:19:16 d2.utils.events]:  eta: 0:02:05  iter: 2099  total_loss: 0.258  loss_cls: 0.05174  loss_box_reg: 0.1939  loss_rpn_cls: 0.0003336  loss_rpn_loc: 0.0053    time: 0.3111  last_time: 0.3229  data_time: 0.0108  last_data_time: 0.0244   lr: 0.0025  max_mem: 1738M
# [10/03 16:19:23 d2.utils.events]:  eta: 0:01:59  iter: 2119  total_loss: 0.2603  loss_cls: 0.06476  loss_box_reg: 0.2012  loss_rpn_cls: 0.0003202  loss_rpn_loc: 0.005839    time: 0.3111  last_time: 0.3522  data_time: 0.0118  last_data_time: 0.0157   lr: 0.0025  max_mem: 1738M
# [10/03 16:19:29 d2.utils.events]:  eta: 0:01:53  iter: 2139  total_loss: 0.2516  loss_cls: 0.04978  loss_box_reg: 0.1917  loss_rpn_cls: 0.0004454  loss_rpn_loc: 0.005773    time: 0.3111  last_time: 0.2975  data_time: 0.0115  last_data_time: 0.0230   lr: 0.0025  max_mem: 1738M
# [10/03 16:19:35 d2.utils.events]:  eta: 0:01:46  iter: 2159  total_loss: 0.264  loss_cls: 0.06177  loss_box_reg: 0.1872  loss_rpn_cls: 0.0004097  loss_rpn_loc: 0.005399    time: 0.3111  last_time: 0.3454  data_time: 0.0124  last_data_time: 0.0056   lr: 0.0025  max_mem: 1738M
# [10/03 16:19:41 d2.utils.events]:  eta: 0:01:40  iter: 2179  total_loss: 0.2565  loss_cls: 0.051  loss_box_reg: 0.2  loss_rpn_cls: 0.0003051  loss_rpn_loc: 0.00457    time: 0.3112  last_time: 0.3107  data_time: 0.0073  last_data_time: 0.0063   lr: 0.0025  max_mem: 1738M
# [10/03 16:19:48 d2.utils.events]:  eta: 0:01:34  iter: 2199  total_loss: 0.2421  loss_cls: 0.05579  loss_box_reg: 0.1844  loss_rpn_cls: 0.0003563  loss_rpn_loc: 0.004711    time: 0.3113  last_time: 0.3169  data_time: 0.0147  last_data_time: 0.0124   lr: 0.0025  max_mem: 1738M
# [10/03 16:19:54 d2.utils.events]:  eta: 0:01:27  iter: 2219  total_loss: 0.2557  loss_cls: 0.04824  loss_box_reg: 0.2068  loss_rpn_cls: 0.0002883  loss_rpn_loc: 0.004441    time: 0.3112  last_time: 0.2736  data_time: 0.0078  last_data_time: 0.0054   lr: 0.0025  max_mem: 1738M
# [10/03 16:20:00 d2.utils.events]:  eta: 0:01:21  iter: 2239  total_loss: 0.2509  loss_cls: 0.06548  loss_box_reg: 0.1816  loss_rpn_cls: 0.0003251  loss_rpn_loc: 0.004793    time: 0.3113  last_time: 0.3017  data_time: 0.0119  last_data_time: 0.0056   lr: 0.0025  max_mem: 1738M
# [10/03 16:20:07 d2.utils.events]:  eta: 0:01:15  iter: 2259  total_loss: 0.2549  loss_cls: 0.05649  loss_box_reg: 0.1816  loss_rpn_cls: 0.0004866  loss_rpn_loc: 0.005611    time: 0.3113  last_time: 0.3170  data_time: 0.0094  last_data_time: 0.0136   lr: 0.0025  max_mem: 1738M
# [10/03 16:20:13 d2.utils.events]:  eta: 0:01:09  iter: 2279  total_loss: 0.2701  loss_cls: 0.05997  loss_box_reg: 0.1979  loss_rpn_cls: 0.0004246  loss_rpn_loc: 0.005461    time: 0.3113  last_time: 0.3097  data_time: 0.0095  last_data_time: 0.0139   lr: 0.0025  max_mem: 1738M
# [10/03 16:20:19 d2.utils.events]:  eta: 0:01:02  iter: 2299  total_loss: 0.2431  loss_cls: 0.05008  loss_box_reg: 0.1728  loss_rpn_cls: 0.0003022  loss_rpn_loc: 0.005818    time: 0.3113  last_time: 0.2999  data_time: 0.0151  last_data_time: 0.0119   lr: 0.0025  max_mem: 1738M
# [10/03 16:20:26 d2.utils.events]:  eta: 0:00:56  iter: 2319  total_loss: 0.2601  loss_cls: 0.05975  loss_box_reg: 0.1867  loss_rpn_cls: 0.0003502  loss_rpn_loc: 0.005122    time: 0.3113  last_time: 0.3119  data_time: 0.0085  last_data_time: 0.0054   lr: 0.0025  max_mem: 1738M
# [10/03 16:20:32 d2.utils.events]:  eta: 0:00:50  iter: 2339  total_loss: 0.2266  loss_cls: 0.04791  loss_box_reg: 0.1695  loss_rpn_cls: 0.000334  loss_rpn_loc: 0.004382    time: 0.3114  last_time: 0.3113  data_time: 0.0097  last_data_time: 0.0052   lr: 0.0025  max_mem: 1738M
# [10/03 16:20:38 d2.utils.events]:  eta: 0:00:43  iter: 2359  total_loss: 0.2661  loss_cls: 0.06743  loss_box_reg: 0.1757  loss_rpn_cls: 0.0003322  loss_rpn_loc: 0.004455    time: 0.3114  last_time: 0.3462  data_time: 0.0095  last_data_time: 0.0061   lr: 0.0025  max_mem: 1738M
# [10/03 16:20:45 d2.utils.events]:  eta: 0:00:37  iter: 2379  total_loss: 0.2525  loss_cls: 0.05365  loss_box_reg: 0.1876  loss_rpn_cls: 0.0004073  loss_rpn_loc: 0.005508    time: 0.3115  last_time: 0.3307  data_time: 0.0105  last_data_time: 0.0058   lr: 0.0025  max_mem: 1738M
# [10/03 16:20:51 d2.utils.events]:  eta: 0:00:31  iter: 2399  total_loss: 0.2472  loss_cls: 0.0493  loss_box_reg: 0.1809  loss_rpn_cls: 0.0006589  loss_rpn_loc: 0.00498    time: 0.3114  last_time: 0.2819  data_time: 0.0115  last_data_time: 0.0117   lr: 0.0025  max_mem: 1738M
# [10/03 16:20:57 d2.utils.events]:  eta: 0:00:25  iter: 2419  total_loss: 0.25  loss_cls: 0.06121  loss_box_reg: 0.1837  loss_rpn_cls: 0.0004617  loss_rpn_loc: 0.003979    time: 0.3113  last_time: 0.3591  data_time: 0.0103  last_data_time: 0.0186   lr: 0.0025  max_mem: 1738M
# [10/03 16:21:03 d2.utils.events]:  eta: 0:00:18  iter: 2439  total_loss: 0.2429  loss_cls: 0.05681  loss_box_reg: 0.1787  loss_rpn_cls: 0.0004313  loss_rpn_loc: 0.005877    time: 0.3114  last_time: 0.3125  data_time: 0.0127  last_data_time: 0.0051   lr: 0.0025  max_mem: 1738M
# [10/03 16:21:09 d2.utils.events]:  eta: 0:00:12  iter: 2459  total_loss: 0.2512  loss_cls: 0.05356  loss_box_reg: 0.1814  loss_rpn_cls: 0.0004063  loss_rpn_loc: 0.004846    time: 0.3113  last_time: 0.2956  data_time: 0.0081  last_data_time: 0.0054   lr: 0.0025  max_mem: 1738M
# [10/03 16:21:15 d2.utils.events]:  eta: 0:00:06  iter: 2479  total_loss: 0.2162  loss_cls: 0.04382  loss_box_reg: 0.1627  loss_rpn_cls: 0.0004924  loss_rpn_loc: 0.00401    time: 0.3113  last_time: 0.2814  data_time: 0.0108  last_data_time: 0.0144   lr: 0.0025  max_mem: 1738M
# [10/03 16:21:28 d2.utils.events]:  eta: 0:00:00  iter: 2499  total_loss: 0.2509  loss_cls: 0.05866  loss_box_reg: 0.1845  loss_rpn_cls: 0.0003079  loss_rpn_loc: 0.005253    time: 0.3112  last_time: 0.3179  data_time: 0.0088  last_data_time: 0.0124   lr: 0.0025  max_mem: 1738M
# [10/03 16:21:28 d2.engine.hooks]: Overall training speed: 2498 iterations in 0:12:57 (0.3112 s / it)
# [10/03 16:21:28 d2.engine.hooks]: Total training time: 0:13:09 (0:00:11 on hooks)
# WARNING [10/03 16:21:28 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [10/03 16:21:28 d2.data.datasets.coco]: Loaded 113 images in COCO format from test/_annotations.coco.json
# [10/03 16:21:28 d2.data.build]: Distribution of instances among all 4 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   apple    | 79           |   banana   | 160          |   orange   | 53           |
# |    pear    | 37           |            |              |            |              |
# |   total    | 329          |            |              |            |              |
# [10/03 16:21:28 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/03 16:21:28 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/03 16:21:28 d2.data.common]: Serializing 113 elements to byte tensors and concatenating them all ...
# [10/03 16:21:28 d2.data.common]: Serialized dataset takes 0.04 MiB
# WARNING [10/03 16:21:28 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader
from detectron2.checkpoint import DetectionCheckpointer
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader
from detectron2.engine import DefaultTrainer

# Configurar la configuración de Detectron2 para evaluación
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TEST = ("fruit_dataset_test",)  # Dataset de prueba
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = "frutas_deteccion_objetos/model_final.pth"  # Ruta de tu modelo guardado
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 4  # Número de clases
cfg.MODEL.DEVICE = "cuda"  # O "cpu" si no tienes GPU

# Cargar el modelo entrenado sin iniciar de nuevo el entrenamiento
model = DefaultTrainer.build_model(cfg)
DetectionCheckpointer(model).load(cfg.MODEL.WEIGHTS)

# Crear el evaluador y el dataloader de prueba
evaluator = COCOEvaluator("fruit_dataset_test", cfg, False, output_dir="./output/")
val_loader = build_detection_test_loader(cfg, "fruit_dataset_test")

# Ejecutar la evaluación y obtener las métricas
metrics = inference_on_dataset(model, val_loader, evaluator)
print(metrics)
# Out:
# [10/03 16:53:54 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=5, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=16, bias=True)
#     )
#   )
# )
# [10/03 16:53:54 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from frutas_deteccion_objetos/model_final.pth ...
# /usr/local/lib/python3.10/dist-packages/fvcore/common/checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))
# WARNING [10/03 16:53:55 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# WARNING [10/03 16:53:55 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [10/03 16:53:55 d2.data.datasets.coco]: Loaded 113 images in COCO format from test/_annotations.coco.json
# [10/03 16:53:55 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/03 16:53:55 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/03 16:53:55 d2.data.common]: Serializing 113 elements to byte tensors and concatenating them all ...
# [10/03 16:53:55 d2.data.common]: Serialized dataset takes 0.04 MiB
# [10/03 16:53:55 d2.evaluation.evaluator]: Start inference on 113 batches
# [10/03 16:53:56 d2.evaluation.evaluator]: Inference done 11/113. Dataloading: 0.0014 s/iter. Inference: 0.0772 s/iter. Eval: 0.0002 s/iter. Total: 0.0788 s/iter. ETA=0:00:08
# [10/03 16:54:01 d2.evaluation.evaluator]: Inference done 72/113. Dataloading: 0.0043 s/iter. Inference: 0.0780 s/iter. Eval: 0.0003 s/iter. Total: 0.0827 s/iter. ETA=0:00:03
# [10/03 16:54:04 d2.evaluation.evaluator]: Total inference time: 0:00:08.963994 (0.083000 s / iter per device, on 1 devices)
# [10/03 16:54:04 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:08 (0.078323 s / iter per device, on 1 devices)
# [10/03 16:54:04 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/03 16:54:04 d2.evaluation.coco_evaluation]: Saving results to ./output/coco_instances_results.json
# [10/03 16:54:04 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [10/03 16:54:04 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [10/03 16:54:04 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [10/03 16:54:04 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [10/03 16:54:04 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.815
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.977
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.974
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.803
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.832
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.859
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.859
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.851
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.860
# [10/03 16:54:04 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 81.519 | 97.747 | 97.412 |  nan  | 80.339 | 83.206 |
# [10/03 16:54:04 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [10/03 16:54:04 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | apple      | 79.230 | banana     | 76.868 | orange     | 84.743 |
# | pear       | 85.234 |            |        |            |        |
# OrderedDict([('bbox', {'AP': 81.51877672348041, 'AP50': 97.74664545362309, 'AP75': 97.4117484797646, 'APs': nan, 'APm': 80.33925458732666, 'APl': 83.20624401368785, 'AP-apple': 79.22993828155299, 'AP-banana': 76.86777844143384, 'AP-orange': 84.74342748783641, 'AP-pear': 85.23396268309843})])

# %% [markdown]
# GUARDAMOS MODELO EN DRIVE

# %%
import shutil

src = '/content/frutas_deteccion_objetos'
dst = '/content/drive/MyDrive/modelos_entrenados/frutas_deteccion_objetos'
shutil.copytree(src, dst)
# Out:
# '/content/drive/MyDrive/modelos_entrenados/frutas_deteccion_objetos'
