# %%
# !pip install  pydantic numpy opencv-python  gdown torch torchvision torchaudio
# !pip install requests git+https://github.com/facebookresearch/detectron2.git supervision
# Out:
# Requirement already satisfied: pydantic in ./.venv/lib/python3.10/site-packages (2.9.2)
# Requirement already satisfied: numpy in ./.venv/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: gdown in ./.venv/lib/python3.10/site-packages (5.2.0)
# Requirement already satisfied: torch in ./.venv/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.10/site-packages (0.17.2)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.10/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in ./.venv/lib/python3.10/site-packages (from pydantic) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./.venv/lib/python3.10/site-packages (from pydantic) (4.12.2)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.10/site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in ./.venv/lib/python3.10/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.10/site-packages (from gdown) (4.66.5)
# Requirement already satisfied: sympy in ./.venv/lib/python3.10/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in ./.venv/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.10/site-packages (from torch) (2024.9.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.venv/lib/python3.10/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in ./.venv/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /private/var/folders/w_/p2v_3ws53kb94pjj9vj9m_m00000gn/T/pip-req-build-xl1tn1lf
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /private/var/folders/w_/p2v_3ws53kb94pjj9vj9m_m00000gn/T/pip-req-build-xl1tn1lf
#   Resolved https://github.com/facebookresearch/detectron2.git to commit ebe8b45437f86395352ab13402ba45b75b4d1ddb
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in ./.venv/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: supervision in ./.venv/lib/python3.10/site-packages (0.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests) (2024.8.30)
# Requirement already satisfied: Pillow>=7.1 in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (10.4.0)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (3.9.2)
# Requirement already satisfied: pycocotools>=2.0.2 in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (2.0.8)
# Requirement already satisfied: termcolor>=1.1 in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (2.4.0)
# Requirement already satisfied: yacs>=0.1.8 in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (0.1.8)
# Requirement already satisfied: tabulate in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (3.0.0)
# Requirement already satisfied: tqdm>4.29.0 in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (4.66.5)
# Requirement already satisfied: tensorboard in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (2.18.0)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (1.3.2)
# Requirement already satisfied: black in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (24.8.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from detectron2==0.6) (24.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in ./.venv/lib/python3.10/site-packages (from supervision) (0.7.1)
# Requirement already satisfied: numpy>=1.23.3 in ./.venv/lib/python3.10/site-packages (from supervision) (1.26.4)
# Requirement already satisfied: opencv-python-headless>=4.5.5.64 in ./.venv/lib/python3.10/site-packages (from supervision) (4.10.0.84)
# Requirement already satisfied: pyyaml>=5.3 in ./.venv/lib/python3.10/site-packages (from supervision) (6.0.2)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in ./.venv/lib/python3.10/site-packages (from supervision) (1.14.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in ./.venv/lib/python3.10/site-packages (from hydra-core>=1.1->detectron2==0.6) (4.9.3)
# Requirement already satisfied: portalocker in ./.venv/lib/python3.10/site-packages (from iopath<0.1.10,>=0.1.7->detectron2==0.6) (2.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (2.9.0.post0)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.10/site-packages (from black->detectron2==0.6) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./.venv/lib/python3.10/site-packages (from black->detectron2==0.6) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in ./.venv/lib/python3.10/site-packages (from black->detectron2==0.6) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in ./.venv/lib/python3.10/site-packages (from black->detectron2==0.6) (4.3.6)
# Requirement already satisfied: tomli>=1.1.0 in ./.venv/lib/python3.10/site-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in ./.venv/lib/python3.10/site-packages (from black->detectron2==0.6) (4.12.2)
# Requirement already satisfied: absl-py>=0.4 in ./.venv/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in ./.venv/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.66.2)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in ./.venv/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (5.28.2)
# Requirement already satisfied: setuptools>=41.0.0 in ./.venv/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (74.1.3)
# Requirement already satisfied: six>1.9 in ./.venv/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.5)

# %% [markdown]
# ##  Descargamos archivos
# Descargamos archivos que vamos a usar para probar nuestro programa

# %%
import gdown
import os
import shutil


def download_from_drive(url, output_dir):
    """
    Downloads the folder from Google Drive to the specified output directory.
    If the directory already exists, it will be removed and replaced by the new download.

    Parameters:
    - url (str): The URL of the Google Drive folder.
    - output_dir (str): The directory where the folder will be downloaded.
    """
    if os.path.exists(output_dir):
        shutil.rmtree(output_dir)
    os.makedirs(output_dir)
    gdown.download_folder(url, output=output_dir, quiet=False)
    print(f"Download completed and replaced the folder: {output_dir}.")

url_other = 'https://drive.google.com/drive/folders/15vMYnhA1zBOn2Ua69O01ZdbnpkMYLHFn?usp=sharing'
output_dir_other = 'fotos_frutas'
download_from_drive(url_other, output_dir_other)

url_videos = 'https://drive.google.com/drive/folders/1WMS-g-gzp-ku1HGs9AW3EonUSBVWb1fJ'
output_dir_videos = 'videos_frutas'
download_from_drive(url_videos, output_dir_videos)

url_other = 'https://drive.google.com/drive/u/1/folders/1_8HTzIySFfDBcB_quHgIL7w3AVd6fD0F'
output_dir_other = '_modelos'
download_from_drive(url_other, output_dir_other)
# Out:
# Retrieving folder contents
# Processing file 1bCyS39ZrAq-uwWHGXJTKGCS90JmqgzpW 1.jpeg
B/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-XjDJXecNFSRwaZvcjm-9xR5MFxmVKWq
# To: /Users/pepeargentoo/CV_tp/_modelos/frutas_deteccion_objetos/last_checkpoint
# 100%|██████████| 15.0/15.0 [00:00<00:00, 32.2kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-fCr6dGNSO66E4iEjbg0ogeUjMjbvbOH
# To: /Users/pepeargentoo/CV_tp/_modelos/frutas_deteccion_objetos/metrics.json
# 100%|██████████| 75.5k/75.5k [00:00<00:00, 1.02MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1-NBJbVqkznlvU_57QlnuQPmvhI-o117Y
# From (redirected): https://drive.google.com/uc?id=1-NBJbVqkznlvU_57QlnuQPmvhI-o117Y&confirm=t&uuid=30ea584b-a3b6-41ca-ae89-2510bcdac1d7
# To: /Users/pepeargentoo/CV_tp/_modelos/frutas_deteccion_objetos/model_final.pth
# 100%|██████████| 330M/330M [00:58<00:00, 5.61MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-0THiAqeN9iLcRka0f1KzBCxofrdkLMQ
# To: /Users/pepeargentoo/CV_tp/_modelos/segmentacion/events.out.tfevents.1727986626.83f7a39597d0.4128.3
# 100%|██████████| 57.1k/57.1k [00:00<00:00, 929kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-4fTt-y8BLrcf7B0N0fvXdb8L3JxVNJw
# To: /Users/pepeargentoo/CV_tp/_modelos/segmentacion/last_checkpoint
# 100%|██████████| 15.0/15.0 [00:00<00:00, 46.7kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-0myCOa9_u3TvDplIfEgUIRjk0Sadwwm
# To: /Users/pepeargentoo/CV_tp/_modelos/segmentacion/metrics.json
# 100%|██████████| 39.7k/39.7k [00:00<00:00, 867kB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1-6kr8PZYdpV1KMHbEYFNZQ4Nu2JyZhlD
# From (redirected): https://drive.google.com/uc?id=1-6kr8PZYdpV1KMHbEYFNZQ4Nu2JyZhlD&confirm=t&uuid=65339851-282d-4da4-b3ce-db0abdd03b1a
# To: /Users/pepeargentoo/CV_tp/_modelos/segmentacion/model_final.pth
# 100%|██████████| 351M/351M [00:43<00:00, 8.04MB/s]
# Download completed and replaced the folder: _modelos.
# Download completed

# %% [markdown]
# ## Instalamos Dependencias

# %%
import cv2
import matplotlib.pyplot as plt
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2 import model_zoo
import numpy as np
from abc import ABC, abstractmethod

# %% [markdown]
# Decidimos utilizar el patrón estrategia en este sistema de segmentación de frutas para hacer más flexible y simple el cálculo del peso de diferentes frutas, que varían en forma y características. Cada fruta, como la manzana, la banana, o la naranja, tiene una forma diferente (esfera, cilindro, etc.), y sus propiedades como el peso o el volumen también difieren. Con el patrón estrategia, podemos encapsular estos cálculos en clases separadas, lo que facilita mucho el trabajo: cada tipo de fruta tiene su propia "estrategia" para calcular su peso.

# %%
class FruitStrategy(ABC):
    """
    Interfaz para definir estrategias de cálculo de peso de frutas.
    """

    @abstractmethod
    def calcular_peso(self, mask, escala_pix_cm2):
        """
        Calcula el peso de la fruta a partir de la máscara de segmentación y la escala de píxeles a cm².

        :param mask: Máscara binaria de la fruta.
        :param escala_pix_cm2: Escala de píxeles a centímetros cuadrados.
        :return: Peso estimado en gramos.
        """
        pass

    @abstractmethod
    def obtener_diametro_real(self):
        """
        Obtiene el diámetro promedio de la fruta en cm.

        :return: Diámetro promedio en cm.
        """
        pass

# %%
class AppleStrategy(FruitStrategy):
    """
    Estrategia de cálculo de peso para una manzana, aproximada a una esfera.
    """
    densidad = 0.9
    diametro_promedio = 8
    peso_min = 100
    peso_max = 230

    def calcular_peso(self, mask, escala_pix_cm2):
        area_pixeles = np.sum(mask)
        area_cm2 = area_pixeles * escala_pix_cm2
        radio_cm = np.sqrt(area_cm2 / np.pi)
        volumen_aprox = (4 / 3) * np.pi * (radio_cm ** 3)
        peso_estimado = AppleStrategy.densidad * volumen_aprox
        return max(AppleStrategy.peso_min, min(peso_estimado, AppleStrategy.peso_max))

    def obtener_diametro_real(self):
        return AppleStrategy.diametro_promedio

# %%
class BananaStrategy(FruitStrategy):
    """
    Estrategia de cálculo de peso para una banana, aproximada a un cilindro.
    """
    densidad = 0.94
    longitud_promedio = 20
    diametro_promedio = 3.5
    peso_min = 80
    peso_max = 200

    def calcular_peso(self, mask, escala_pix_cm2):
        radio_cm = self.diametro_promedio / 2
        volumen_aprox = np.pi * (radio_cm ** 2) * BananaStrategy.longitud_promedio
        peso_estimado = BananaStrategy.densidad * volumen_aprox
        return max(BananaStrategy.peso_min, min(peso_estimado, BananaStrategy.peso_max))

    def obtener_diametro_real(self):
        return BananaStrategy.diametro_promedio

# %%
class OrangeStrategy(FruitStrategy):
    """
    Estrategia de cálculo de peso para una naranja, aproximada a una esfera.
    """
    densidad = 0.96
    diametro_promedio = 7.5
    peso_min = 120
    peso_max = 210

    def calcular_peso(self, mask, escala_pix_cm2):
        area_pixeles = np.sum(mask)
        area_cm2 = area_pixeles * escala_pix_cm2
        radio_cm = np.sqrt(area_cm2 / np.pi)
        volumen_aprox = (4 / 3) * np.pi * (radio_cm ** 3)
        peso_estimado = OrangeStrategy.densidad * volumen_aprox
        return max(OrangeStrategy.peso_min, min(peso_estimado, OrangeStrategy.peso_max))

    def obtener_diametro_real(self):
        return OrangeStrategy.diametro_promedio

# %%
class PearStrategy(FruitStrategy):
    """
    Estrategia de cálculo de peso para una pera, aproximada a una esfera con menor densidad.
    """
    densidad = 0.6
    diametro_promedio = 6
    peso_min = 100
    peso_max = 160

    def calcular_peso(self, mask, escala_pix_cm2):
        area_pixeles = np.sum(mask)
        area_cm2 = area_pixeles * escala_pix_cm2
        radio_cm = np.sqrt(area_cm2 / np.pi)
        volumen_aprox = (4 / 3) * np.pi * (radio_cm ** 3)
        peso_estimado = PearStrategy.densidad * volumen_aprox
        return max(PearStrategy.peso_min, min(peso_estimado, PearStrategy.peso_max))

    def obtener_diametro_real(self):
        return PearStrategy.diametro_promedio

# %% [markdown]
# La clase **SegmentationProcessor** fue diseñada para resolver el problema de segmentación de frutas y cálculo de su peso utilizando un modelo preentrenado de detección de instancias, como Mask R-CNN. Esta clase abstrae el proceso de trabajar con imágenes y videos, simplificando el flujo de trabajo desde la carga del modelo hasta la predicción de los objetos presentes en una imagen o video en tiempo real.
#
# Uno de los principales objetivos de esta clase es hacer el código modular y flexible. Para esto, se introduce la capacidad de procesar no solo imágenes individuales, sino también secuencias de video o incluso transmisiones en vivo desde una cámara. Además, al trabajar con diferentes tipos de frutas, cada una con sus propias características, la clase también está diseñada para aplicar estrategias específicas para el cálculo del peso de cada fruta, lo que asegura una mayor precisión.
#
# El método process_frame se encarga de aplicar la segmentación sobre un fotograma, identificar las frutas, y calcular su peso según la estrategia correspondiente. Esto nos permite agregar nuevas frutas o cambiar las estrategias de cálculo sin necesidad de modificar el código base, siguiendo los principios del diseño modular y abierto para la extensión, pero cerrado para la modificación.

# %%
class SegmentationProcessor:
    """
    Procesador de segmentación para calcular el peso de frutas utilizando un modelo preentrenado.
    """

    def __init__(self, model_path, class_names, thresholds_per_class, delay=2000, estrategias=None, device='cpu'):
        """
        Inicializa el procesador con la configuración del modelo y las estrategias de frutas.

        :param model_path: Ruta al modelo entrenado.
        :param class_names: Lista de nombres de las clases de frutas.
        :param thresholds_per_class: Umbrales por clase para las detecciones.
        :param delay: Tiempo de retención de la predicción en milisegundos.
        :param estrategias: Diccionario de estrategias de frutas.
        :param device: Dispositivo a utilizar ('cpu' o 'cuda').
        """
        self.class_names = class_names
        self.thresholds_per_class = thresholds_per_class
        self.delay = delay
        self.estrategias = estrategias

        self.cfg = get_cfg()
        self.cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
        self.cfg.MODEL.WEIGHTS = model_path
        self.cfg.MODEL.ROI_HEADS.NUM_CLASSES = len(class_names)
        self.cfg.MODEL.DEVICE = device
        self.predictor = DefaultPredictor(self.cfg)

    def calcular_escala_automatica(self, diametro_promedio_px, diametro_real_cm):
        """
        Calcula la escala de píxeles a cm² en base al diámetro promedio en píxeles.

        :param diametro_promedio_px: Diámetro promedio en píxeles.
        :param diametro_real_cm: Diámetro real en centímetros.
        :return: Escala de píxeles a cm².
        """
        return (diametro_real_cm ** 2) / (np.pi * (diametro_promedio_px / 2) ** 2)

    def process_frame(self, frame):
        """
        Procesa un fotograma para realizar la segmentación y cálculo del peso de las frutas.

        :param frame: Imagen de entrada.
        :return: Imagen con la segmentación y el peso calculado.
        """
        outputs = self.predictor(frame)
        instances = outputs["instances"].to("cpu")
        pred_classes = instances.pred_classes if instances.has("pred_classes") else None
        pred_masks = instances.pred_masks if instances.has("pred_masks") else None
        scores = instances.scores if instances.has("scores") else None

        mask_image = np.zeros_like(frame)

        if pred_masks is not None:
            for i, mask in enumerate(pred_masks):
                class_id = pred_classes[i].item()
                class_name = self.class_names[class_id]
                class_threshold = self.thresholds_per_class[class_name]

                if scores[i] > class_threshold:
                    mask = mask.numpy()
                    mask_image[mask] = [0, 255, 0]

                    estrategia = self.estrategias.get(class_name.lower())
                    if estrategia:
                        contours, _ = cv2.findContours(mask.astype(np.uint8),
                                                       cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                        largest_contour = max(contours, key=cv2.contourArea)
                        x, y, w, h = cv2.boundingRect(largest_contour)
                        diametro_promedio_px = (w + h) / 2
                        escala_pix_cm2 = self.calcular_escala_automatica(diametro_promedio_px,
                                                                         estrategia.obtener_diametro_real())
                        peso_estimado = estrategia.calcular_peso(mask, escala_pix_cm2)

                        cv2.drawContours(frame, [largest_contour], -1, (0, 255, 0), 2)
                        texto = f'{class_name.capitalize()}: {peso_estimado:.2f} g'
                        cv2.putText(frame, texto, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0, 0, 255), 3)

        combined_image = cv2.addWeighted(frame, 1, mask_image, 0.5, 0)
        return combined_image

    def process_image(self, image_path):
        """
        Procesa una imagen estática.

        :param image_path: Ruta de la imagen a procesar.
        """
        image = cv2.imread(image_path)
        result = self.process_frame(image)
        plt.figure(figsize=(10, 10))
        plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
        plt.axis("off")
        plt.show()

    def process_video(self, video_path):
        """
        Procesa un archivo de video realizando detecciones cada 60 fotogramas.

        :param video_path: Ruta del archivo de video.
        """
        cap = cv2.VideoCapture(video_path)
        frame_count = 0
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            if frame_count % 60 == 0:
                result = self.process_frame(frame)
                cv2.imshow("Segmentación en Video", result)
                cv2.waitKey(self.delay)
            else:
                cv2.imshow("Segmentación en Video", frame)

            frame_count += 1
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        cap.release()
        cv2.destroyAllWindows()

    def process_camera(self, camera_index=0):
        """
        Procesa el feed de una cámara en tiempo real y realiza detecciones cada 60 fotogramas.

        :param camera_index: Índice de la cámara (0 por defecto).
        """
        cap = cv2.VideoCapture(camera_index)
        frame_count = 0
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            if frame_count % 60 == 0:
                result = self.process_frame(frame)
                cv2.imshow("Segmentación en Cámara", result)
                cv2.waitKey(self.delay)
            else:
                cv2.imshow("Segmentación en Cámara", frame)

            frame_count += 1
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        cap.release()
        cv2.destroyAllWindows()

# %% [markdown]
# ## Ejemplo de uso 1
# En este caso vamos a probar con 4 de las mismas frutas

# %%
class_names = ['apple', 'banana', 'orange', 'pear']
thresholds_per_class = {
    'apple': 0.85,
    'banana': 0.80,
    'orange': 0.85,
    'pear': 0.20
}

estrategias_frutas = {
    'apple': AppleStrategy(),
    'banana': BananaStrategy(),
    'orange': OrangeStrategy(),
    'pear': PearStrategy()
}

model_path = "_modelos/segmentacion/model_final.pth"

processor = SegmentationProcessor(model_path, class_names, thresholds_per_class, delay=2000,
                                  estrategias=estrategias_frutas)

processor.process_image("fotos_frutas/1.jpeg")

# %% [markdown]
# ## Ejemplo de uso 2

# %%
class_names = ['apple', 'banana', 'orange', 'pear']
thresholds_per_class = {
    'apple': 0.85,
    'banana': 0.80,
    'orange': 0.85,
    'pear': 0.20
}

estrategias_frutas = {
    'apple': AppleStrategy(),
    'banana': BananaStrategy(),
    'orange': OrangeStrategy(),
    'pear': PearStrategy()
}

model_path = "_modelos/segmentacion/model_final.pth"

processor = SegmentationProcessor(model_path, class_names, thresholds_per_class, delay=2000,
                                  estrategias=estrategias_frutas)

processor.process_image("fotos_frutas/2.jpeg")

# %% [markdown]
# # Ejemplo 3

# %%
class_names = ['apple', 'banana', 'orange', 'pear']
thresholds_per_class = {
    'apple': 0.85,
    'banana': 0.80,
    'orange': 0.85,
    'pear': 0.20
}

estrategias_frutas = {
    'apple': AppleStrategy(),
    'banana': BananaStrategy(),
    'orange': OrangeStrategy(),
    'pear': PearStrategy()
}

model_path = "_modelos/segmentacion/model_final.pth"

processor = SegmentationProcessor(model_path, class_names, thresholds_per_class, delay=2000,
                                  estrategias=estrategias_frutas)

processor.process_image("fotos_frutas/8.jpeg")

# %% [markdown]
# # Ejemplo con camara web

# %%
class_names = ['apple', 'banana', 'orange', 'pear']
thresholds_per_class = {
    'apple': 0.5,
    'banana': 0.60,
    'orange': 0.5,
    'pear': 0.03
}

estrategias_frutas = {
    'apple': AppleStrategy(),
    'banana': BananaStrategy(),
    'orange': OrangeStrategy(),
    'pear': PearStrategy()
}

model_path = "_modelos/segmentacion/model_final.pth"

processor = SegmentationProcessor(model_path, class_names, thresholds_per_class, delay=10,
                                  estrategias=estrategias_frutas)

processor.process_camera()
# Out:
# 2024-10-04 21:32:24.049 Python[19634:1208219] +[IMKClient subclass]: chose IMKClient_Legacy
# 2024-10-04 21:32:24.049 Python[19634:1208219] +[IMKInputSession subclass]: chose IMKInputSession_Legacy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 21
#      16 model_path = "_modelos/segmentacion/model_final.pth"
#      18 processor = SegmentationProcessor(model_path, class_names, thresholds_per_class, delay=2000,
#      19                                   estrategias=estrategias_frutas)
# ---> 21 processor.process_camera()
#
# Cell In[10], line 136, in SegmentationProcessor.process_camera(self, camera_index)
#     133     break
#     135 if frame_count % 60 == 0:
# --> 136     result = self.process_frame(frame)
#     137     cv2.imshow("Segmentación en Cámara", result)
#     138     cv2.waitKey(self.delay)
#
# Cell In[10], line 46, in SegmentationProcessor.process_frame(self, frame)
#      39 def process_frame(self, frame):
#      40     """
#      41     Procesa un fotograma para realizar la segmentación y cálculo del peso de las frutas.
#      42
#      43     :param frame: Imagen de entrada.
#      44     :return: Imagen con la segmentación y el peso calculado.
#      45     """
# ---> 46     outputs = self.predictor(frame)
#      47     instances = outputs["instances"].to("cpu")
#      48     pred_classes = instances.pred_classes if instances.has("pred_classes") else None
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/detectron2/engine/defaults.py:351, in DefaultPredictor.__call__(self, original_image)
#     347 image.to(self.cfg.MODEL.DEVICE)
#     349 inputs = {"image": image, "height": height, "width": width}
# --> 351 predictions = self.model([inputs])[0]
#     352 return predictions
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/detectron2/modeling/meta_arch/rcnn.py:150, in GeneralizedRCNN.forward(self, batched_inputs)
#     127 """
#     128 Args:
#     129     batched_inputs: a list, batched outputs of :class:`DatasetMapper` .
#    (...)
#     147         "pred_boxes", "pred_classes", "scores", "pred_masks", "pred_keypoints"
#     148 """
#     149 if not self.training:
# --> 150     return self.inference(batched_inputs)
#     152 images = self.preprocess_image(batched_inputs)
#     153 if "instances" in batched_inputs[0]:
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/detectron2/modeling/meta_arch/rcnn.py:208, in GeneralizedRCNN.inference(self, batched_inputs, detected_instances, do_postprocess)
#     206 if detected_instances is None:
#     207     if self.proposal_generator is not None:
# --> 208         proposals, _ = self.proposal_generator(images, features, None)
#     209     else:
#     210         assert "proposals" in batched_inputs[0]
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/detectron2/modeling/proposal_generator/rpn.py:454, in RPN.forward(self, images, features, gt_instances)
#     451 features = [features[f] for f in self.in_features]
#     452 anchors = self.anchor_generator(features)
# --> 454 pred_objectness_logits, pred_anchor_deltas = self.rpn_head(features)
#     455 # Transpose the Hi*Wi*A dimension to the middle:
#     456 pred_objectness_logits = [
#     457     # (N, A, Hi, Wi) -> (N, Hi, Wi, A) -> (N, Hi*Wi*A)
#     458     score.permute(0, 2, 3, 1).flatten(1)
#     459     for score in pred_objectness_logits
#     460 ]
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/detectron2/modeling/proposal_generator/rpn.py:174, in StandardRPNHead.forward(self, features)
#     172 pred_anchor_deltas = []
#     173 for x in features:
# --> 174     t = self.conv(x)
#     175     pred_objectness_logits.append(self.objectness_logits(t))
#     176     pred_anchor_deltas.append(self.anchor_deltas(t))
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/CV_tp/.venv/lib/python3.10/site-packages/detectron2/layers/wrappers.py:142, in Conv2d.forward(self, x)
#     136             if x.numel() == 0 and self.training:
#     137                 # https://github.com/pytorch/pytorch/issues/12013
#     138                 assert not isinstance(
#     139                     self.norm, torch.nn.SyncBatchNorm
#     140                 ), "SyncBatchNorm does not support empty inputs!"
# --> 142 x = F.conv2d(
#     143     x, self.weight, self.bias, self.stride, self.padding, self.dilation, self.groups
#     144 )
#     145 if self.norm is not None:
#     146     x = self.norm(x)
#
# KeyboardInterrupt:

# %% [markdown]
# # Ejemplo Videos 1

# %%
class_names = ['apple', 'banana', 'orange', 'pear']
thresholds_per_class = {
    'apple': 0.85,
    'banana': 0.80,
    'orange': 0.5,
    'pear': 0.20
}

estrategias_frutas = {
    'apple': AppleStrategy(),
    'banana': BananaStrategy(),
    'orange': OrangeStrategy(),
    'pear': PearStrategy()
}

model_path = "_modelos/segmentacion/model_final.pth"

processor = SegmentationProcessor(model_path, class_names, thresholds_per_class, delay=1,
                                  estrategias=estrategias_frutas)

processor.process_video('videos_frutas/20241001_185531.mp4')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 21
#      16 model_path = "_modelos/segmentacion/model_final.pth"
#      18 processor = SegmentationProcessor(model_path, class_names, thresholds_per_class, delay=1,
#      19                                   estrategias=estrategias_frutas)
# ---> 21 processor.process_video('videos_frutas/20241001_185531.mp4')
#
# Cell In[8], line 104, in SegmentationProcessor.process_video(self, video_path)
#     102 frame_count = 0
#     103 while cap.isOpened():
# --> 104     ret, frame = cap.read()
#     105     if not ret:
#     106         break
#
# KeyboardInterrupt:

# %% [markdown]
# # Ejemplo Videos 2

# %%
class_names = ['apple', 'banana', 'orange', 'pear']
thresholds_per_class = {
    'apple': 0.5,
    'banana': 0.80,
    'orange': 0.5,
    'pear': 0.20
}

estrategias_frutas = {
    'apple': AppleStrategy(),
    'banana': BananaStrategy(),
    'orange': OrangeStrategy(),
    'pear': PearStrategy()
}

model_path = "_modelos/segmentacion/model_final.pth"

processor = SegmentationProcessor(model_path, class_names, thresholds_per_class, delay=1,
                                  estrategias=estrategias_frutas)

processor.process_video('videos_frutas/20241001_185753.mp4')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 21
#      16 model_path = "_modelos/segmentacion/model_final.pth"
#      18 processor = SegmentationProcessor(model_path, class_names, thresholds_per_class, delay=1,
#      19                                   estrategias=estrategias_frutas)
# ---> 21 processor.process_video('videos_frutas/20241001_185753.mp4')
#
# Cell In[8], line 116, in SegmentationProcessor.process_video(self, video_path)
#     113         cv2.imshow("Segmentación en Video", frame)
#     115     frame_count += 1
# --> 116     if cv2.waitKey(1) & 0xFF == ord('q'):
#     117         break
#     119 cap.release()
#
# KeyboardInterrupt:

# %% [markdown]
# # Ejemplo Video 3

# %%
class_names = ['apple', 'banana', 'orange', 'pear']
thresholds_per_class = {
    'apple': 0.5,
    'banana': 0.60,
    'orange': 0.5,
    'pear': 0.03
}

estrategias_frutas = {
    'apple': AppleStrategy(),
    'banana': BananaStrategy(),
    'orange': OrangeStrategy(),
    'pear': PearStrategy()
}

model_path = "_modelos/segmentacion/model_final.pth"

processor = SegmentationProcessor(model_path, class_names, thresholds_per_class, delay=1000,
                                  estrategias=estrategias_frutas)

processor.process_video('videos_frutas/20241002_205348.mp4')
